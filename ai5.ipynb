# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
df = pd.read_csv("D:/titanic-passengers.csv",sep =';')
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
column_names = df.columns
for column in column_names:
    print(column + ' - ' + str(df[column].isnull().sum()))
# Out:
# PassengerId - 0
# Survived - 0
# Pclass - 0
# Name - 0
# Sex - 0
# Age - 177
# SibSp - 0
# Parch - 0
# Ticket - 0
# Fare - 0
# Cabin - 687
# Embarked - 2

# %%
df['Age'].fillna(df['Age'].mean(),inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0],inplace = True)

# %%
column_names = df.columns
for column in column_names:
    print(column + ' - ' + str(df[column].isnull().sum()))
# Out:
# PassengerId - 0
# Survived - 0
# Pclass - 0
# Name - 0
# Sex - 0
# Age - 0
# SibSp - 0
# Parch - 0
# Ticket - 0
# Fare - 0
# Cabin - 687
# Embarked - 0

# %%
df["Survived"]=df["Survived"].map({"Yes":1,"No":0})
df["Sex"]=df["Sex"].map({"male":1,"female":0})

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex        Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.000000      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.000000      0
# 2                               Jensen, Mr. Hans Peder    1  20.000000      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    0  29.000000      0
# 4                               Davidson, Mr. Thornton    1  31.000000      1
# ..                                                 ...  ...        ...    ...
# 886                Nasser, Mrs. Nicholas (Adele Achem)    0  14.000000      1
# 887                              Sirayanian, Mr. Orsen    1  22.000000      0
# 888                                Cacic, Miss. Marija    0  30.000000      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    1  29.699118      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...    0  19.000000      0
#
#      Parch      Ticket     Fare  Cabin Embarked
# 0        0      248740  13.0000    NaN        S
# 1        0      348123   7.6500  F G73        S
# 2        0      350050   7.8542    NaN        S
# 3        4      349909  21.0750    NaN        S
# 4        0  F.C. 12750  52.0000    B71        S
# ..     ...         ...      ...    ...      ...
# 886      0      237736  30.0708    NaN        C
# 887      0        2669   7.2292    NaN        C
# 888      0      315084   8.6625    NaN        S
# 889      0      349215   7.8958    NaN        S
# 890      0      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
g=sns.FacetGrid(df,col='Sex', row= 'Survived')
g.map(plt.hist,'Age',bins=10)

# %%
df[["Sex","Age", "Survived"]].groupby(["Survived","Sex"]).mean()
# Out:
#                     Age
# Survived Sex
# 0        0    26.023272
#          1    31.175224
# 1        0    28.979263
#          1    27.631705

# %%
plot_correlation_map( df )

# %%
Title_Dictionary = {

                    "Capt": "Officer",

                    "Col": "Officer",

                    "Major":"Officer",

                    "Dr":"Officer",

                    "Rev":"Officer" ,

                    "Jonkheer":"Royalty",

                    "Don":"Royalty",

                    "Sir" :"Royalty",

                   "Lady" :"Royalty",

                  "the Countess": "Royalty",

                    "Dona":"Royalty",

                    "Mme":"Miss",

                    "Mlle":"Miss",

                    "Miss" :"Miss",

                    "Ms":"Mrs",

                    "Mr" :"Mr",

                    "Mrs" :"Mrs",

                    "Master" :"Master"

                    }

# %%
df.rename(columns={"Name":"Title"},inplace=True)
for i,j in df[['Title']].iterrows():
    for key in Title_Dictionary:
        if key in j['Title']:
            df["Title"][i]=Title_Dictionary.get(key)
# Out:
# C:\Users\mosb2\AppData\Local\Temp\ipykernel_42300\1540371327.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Title"][i]=Title_Dictionary.get(key)

# %%
df
# Out:
#      PassengerId  Survived  Pclass Title  Sex        Age  SibSp  Parch  \
# 0            343         0       2    Mr    1  28.000000      0      0
# 1             76         0       3    Mr    1  25.000000      0      0
# 2            641         0       3    Mr    1  20.000000      0      0
# 3            568         0       3   Mrs    0  29.000000      0      4
# 4            672         0       1    Mr    1  31.000000      1      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886           10         1       2   Mrs    0  14.000000      1      0
# 887           61         0       3    Mr    1  22.000000      0      0
# 888          535         0       3  Miss    0  30.000000      0      0
# 889          102         0       3    Mr    1  29.699118      0      0
# 890          428         1       2   Mrs    0  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked
# 0        248740  13.0000    NaN        S
# 1        348123   7.6500  F G73        S
# 2        350050   7.8542    NaN        S
# 3        349909  21.0750    NaN        S
# 4    F.C. 12750  52.0000    B71        S
# ..          ...      ...    ...      ...
# 886      237736  30.0708    NaN        C
# 887        2669   7.2292    NaN        C
# 888      315084   8.6625    NaN        S
# 889      349215   7.8958    NaN        S
# 890      250655  26.0000    NaN        S
#
# [891 rows x 12 columns]

# %%
family=[]
df['family'] = df['SibSp'] + df['Parch']

# %%
df
# Out:
#      PassengerId  Survived  Pclass Title  Sex        Age  SibSp  Parch  \
# 0            343         0       2    Mr    1  28.000000      0      0
# 1             76         0       3    Mr    1  25.000000      0      0
# 2            641         0       3    Mr    1  20.000000      0      0
# 3            568         0       3   Mrs    0  29.000000      0      4
# 4            672         0       1    Mr    1  31.000000      1      0
# ..           ...       ...     ...   ...  ...        ...    ...    ...
# 886           10         1       2   Mrs    0  14.000000      1      0
# 887           61         0       3    Mr    1  22.000000      0      0
# 888          535         0       3  Miss    0  30.000000      0      0
# 889          102         0       3    Mr    1  29.699118      0      0
# 890          428         1       2   Mrs    0  19.000000      0      0
#
#          Ticket     Fare  Cabin Embarked  family
# 0        248740  13.0000    NaN        S       0
# 1        348123   7.6500  F G73        S       0
# 2        350050   7.8542    NaN        S       0
# 3        349909  21.0750    NaN        S       4
# 4    F.C. 12750  52.0000    B71        S       1
# ..          ...      ...    ...      ...     ...
# 886      237736  30.0708    NaN        C       1
# 887        2669   7.2292    NaN        C       0
# 888      315084   8.6625    NaN        S       0
# 889      349215   7.8958    NaN        S       0
# 890      250655  26.0000    NaN        S       0
#
# [891 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
x = df[['Age', 'Sex','Pclass']]
y = df['Survived']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=0)  
logreg = LogisticRegression()  
logreg.fit(x_train, y_train)  
y_pred  = logreg.predict(x_test)    
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.81

# %%
import seaborn as sns
sns.regplot(x='Age',y='Survived',data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Survived'>

# %%
confusion_matrix = pd.crosstab(y_test, y_pred, rownames=['Actual'], colnames=['Predicted'])
sns.heatmap(confusion_matrix, annot=True)
# Out:
# <AxesSubplot:xlabel='Predicted', ylabel='Actual'>

# %%
import matplotlib.pyplot as plt
def plot_roc_curve(true_y, y_prob):
    true_y, y_prob, thresholds = roc_curve(true_y, y_prob)
    plt.plot(true_y, y_prob)
    plt.xlabel('Age')
    plt.ylabel('Survived')

# %%
plot_roc_curve(y_test, y_pred)
print(f'model 2 AUC score: {roc_auc_score(y_test, y_pred)}')
# Out:
# model 2 AUC score: 0.7878428270042194
